# %%
# Phase 1: Data Acquisition
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Set plotting style
sns.set_style('whitegrid')
# %matplotlib inline

# 1. Define the ticker and date range
ticker_symbol = 'AAPL' 
start_date = '2015-01-01'
end_date = '2024-01-01'

# 2. Fetch Data
print(f"Downloading data for {ticker_symbol}...")
df = yf.download(ticker_symbol, start=start_date, end=end_date)

# 3. Save to 'data' folder
if not os.path.exists('data'):
    os.makedirs('data')

file_name = f"data/{ticker_symbol}_{start_date[:4]}_{end_date[:4]}.csv"
df.to_csv(file_name)

# 4. Show success and plot
print(f"Success! Data saved to: {file_name}")
print(f"Data Shape: {df.shape}")

plt.figure(figsize=(10, 5))
plt.plot(df['Close'], label='Close Price')
plt.title(f'{ticker_symbol} Stock Price (2015-2024)')
plt.legend()
plt.show()
# Out:
# ...
# [*********************100%***********************]  1 of 1 completed
# Success! Data saved to: data/AAPL_2015_2024.csv
# Data Shape: (2264, 5)

# %%
# Phase 2: Feature Engineering

# 1. Create Moving Averages (Trend Indicators)
# SMA_10: Short-term trend (10 days)
df['SMA_10'] = df['Close'].rolling(window=10).mean()
# SMA_50: Medium-term trend (50 days)
df['SMA_50'] = df['Close'].rolling(window=50).mean()

# 2. Create Volatility & Momentum Features
# Daily Return: % change from yesterday
df['Daily_Return'] = df['Close'].pct_change()

# 3. Create the Target Variable (What we want to predict)
# We want to predict the "Next Day's Close Price".
# So we shift the 'Close' column UP by 1 row.
df['Target'] = df['Close'].shift(-1)

# 4. Clean Data (Remove NaNs)
# Moving averages create NaNs at the start.
# Shifting creates a NaN at the very end.
original_rows = len(df)
df.dropna(inplace=True)
print(f"Rows before cleaning: {original_rows}")
print(f"Rows after cleaning: {len(df)}")

# 5. Display the new features
print("\nFirst 5 rows with new features:")
display(df[['Close', 'SMA_10', 'SMA_50', 'Daily_Return', 'Target']].head())

# 6. Save this "Model-Ready" data
df.to_csv('data/AAPL_featured.csv')
print("\nFeature engineering complete! Saved to data/AAPL_featured.csv")# Phase 2: Feature Engineering

# 1. Create Moving Averages (Trend Indicators)
# SMA_10: Short-term trend (10 days)
df['SMA_10'] = df['Close'].rolling(window=10).mean()
# SMA_50: Medium-term trend (50 days)
df['SMA_50'] = df['Close'].rolling(window=50).mean()

# 2. Create Volatility & Momentum Features
# Daily Return: % change from yesterday
df['Daily_Return'] = df['Close'].pct_change()

# 3. Create the Target Variable (What we want to predict)
# We want to predict the "Next Day's Close Price".
# So we shift the 'Close' column UP by 1 row.
df['Target'] = df['Close'].shift(-1)

# 4. Clean Data (Remove NaNs)
# Moving averages create NaNs at the start.
# Shifting creates a NaN at the very end.
original_rows = len(df)
df.dropna(inplace=True)
print(f"Rows before cleaning: {original_rows}")
print(f"Rows after cleaning: {len(df)}")

# 5. Display the new features
print("\nFirst 5 rows with new features:")
display(df[['Close', 'SMA_10', 'SMA_50', 'Daily_Return', 'Target']].head())

# 6. Save this "Model-Ready" data
df.to_csv('data/AAPL_featured.csv')
print("\nFeature engineering complete! Saved to data/AAPL_featured.csv")
# Out:
# Rows before cleaning: 2264
# Rows after cleaning: 2214
#
# First 5 rows with new features:
# Price           Close     SMA_10     SMA_50 Daily_Return     Target
# Ticker           AAPL
# Date
# 2015-03-16  27.783701  27.968036  26.562144     0.011004  28.248428
# 2015-03-17  28.248428  27.916448  26.642815     0.016727  28.566404
# 2015-03-18  28.566404  27.914893  26.743489     0.011256  28.350710
# 2015-03-19  28.350710  27.939129  26.839804    -0.007551  27.994942
# 2015-03-20  27.994942  27.923564  26.922404    -0.012549  28.286232
# Feature engineering complete! Saved to data/AAPL_featured.csv
# Rows before cleaning: 2214
# Rows after cleaning: 2214
#
# First 5 rows with new features:
# Price           Close     SMA_10     SMA_50 Daily_Return     Target
# Ticker           AAPL
# Date
# 2015-03-16  27.783701  27.968036  26.562144     0.011004  28.248428
# 2015-03-17  28.248428  27.916448  26.642815     0.016727  28.566404
# ...

# %%
# Phase 3: Exploratory Data Analysis (EDA) - Trends

plt.figure(figsize=(14, 7))

# Plot the Actual Closing Price
plt.plot(df.index, df['Close'], label='Actual Close Price', alpha=0.5)

# Plot the 10-Day SMA (Fast Trend)
plt.plot(df.index, df['SMA_10'], label='10-Day SMA', color='orange', linestyle='--')

# Plot the 50-Day SMA (Slow Trend)
plt.plot(df.index, df['SMA_50'], label='50-Day SMA', color='green', linestyle='--')

plt.title('Stock Price vs Moving Averages', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.show()

# %%
# Phase 3: EDA - Correlation Heatmap

# Select only numerical columns for correlation
cols_to_check = ['Close', 'SMA_10', 'SMA_50', 'Daily_Return', 'Target']
corr_matrix = df[cols_to_check].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Feature Correlation Matrix', fontsize=16)
plt.show()
